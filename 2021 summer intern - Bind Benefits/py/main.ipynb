# %%
#import library
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import sys
sys.path.append('../../../../DataScience/lib/')
import pymei
from dev.bind_prod_utils import utils as dev_utils
import numpy as np
import race_ebm_funcs as ref

# %%
# presto access credentials
username = input('Enter your jumpcloud username: ')
print('Enter your password:')
conn = pymei.connect.presto(username=username, phi=True, starburst=True)
# Out:
# Enter your jumpcloud username:  Leo.Zhou
# Enter your password:
#  ················

# %%
#get the original data from starburst
end_date = input('EBM end date: ')
race_ebm_df = ref.get_data(conn, end_date)

# %%
# #filter the data based on the ebm end date, select the rows with specified ebm end date
# end_date = input('EBM end date: ') #input need to be in format year-month. Ex. 2020-12
# race_ebm_df  = ref.filter_end_date(race_ebm_df, end_date)

# %%
#create another column for over/underuse
#Create under/overuse based on EBM measure label
underuse = [
#'APP_TOTAL_2020',# - Use of First-Line Psychosocial Care for Children and Adolescents on Antipsychotics (Total)',
'PPC_PN_2020C',#  - Prenatal and Postpartum Care: Prenatal Care',
'PPC_PP_2020C',#  - Prenatal and Postpartum Care: Postpartum Care',
# 'ADD_R1_2020C',#  - Follow-Up Care for Children Prescribed ADHD Medication: Initiation Phase',
# 'ADD_R2_2020C',#  - Follow-Up Care for Children Prescribed ADHD Medication: Continuation & Maintenance Phase',
# 'FUA30_TOTAL_2020',#  - Follow-Up After Emergency Department Visit for Alcohol and Other Drug Abuse or Dependence : 30 days (Overall)',
# 'FUA7_TOTAL_2020',#  - Follow-Up After Emergency Department Visit for Alcohol and Other Drug Abuse or Dependence : 07 days (Overall)',
# 'FUH_30_TOTAL_2020',#  - Follow-Up After Hospitalization for Mental Illness: Total (30 Days Post-Discharge)',
# 'FUH_7_TOTAL_2020',#  - Follow-Up After Hospitalization for Mental Illness: Total (7 Days Post-Discharge)',
# 'FUM_30_TOTAL_2020',#  - Follow-Up After Emergency Department Visit for Mental Illness (Total)-30 Day Follow-Up',
# 'FUM_7_TOTAL_2020',#  - Follow-Up After Emergency Department Visit for Mental Illness (Total)-7 Day Follow-Up',
# 'SAA_2020',#  - Adherence to Antipsychotic Medications for Individuals with Schizophrenia',
# 'SPC_R1_TOTAL_2020',#  - Statin Therapy for Patients with Cardiovascular Disease, Rate 1: Received Statin Therapy (Total)',
# 'SPC_R2_TOTAL_2020',#  - Statin Therapy for Patients with Cardiovascular Disease, Rate 2: Statin Adherence 80% (Total)',
'CDC_A1C_T_2020C',#  - Comprehensive Diabetes Care: Hemoglobin A1c (HbA1c) Testing',
'PQA_BB_2018',#  - Percentage of members 18 years and older who met the PDC threshold of 80% for beta-blockers during the measurement period.',
'PQA_RASA_2018',#  - Percentage of members 18 years and older who met the PDC threshold of 80% for Renin Angiotensin System Antagonists during the measurement period.',
#'NYU_EM_ED_PA_2016',#  - NYU ED Utilization Algorithm: Emergent, ED Care Needed, Preventable/Avoidable',
#'NCS_2020',#  - Non-Recommended Cervical Cancer Screening in Adolescent Females',
'BCS_NON_MCR_2020C',#  - Breast Cancer Screening',
'CHL_TOTAL_2020C',#  - Chlamydia Screening in Women (Total)',
'COL_NON_MCR_2020C',#  - Colorectal Cancer Screening',
'IMA_HPV_2020',#  - Immunizations for Adolescents: HPV Vaccine',
'IMA_MEN_2020',#  - Immunizations for Adolescents: Meningococcal Conjugate or Meningococcal Polysaccharide Vaccine',
'IMA_TD_2020',#  - Immunizations for Adolescents: Tdap Vaccine',
# 'W15_V00_2020C',#  - Well-Child Visits in the First 15 Months of Life: 0 Visits',
# 'W15_V01_2020C',#  - Well-Child Visits in the First 15 Months of Life: 1 Visit',
# 'W15_V02_2020C',#  - Well-Child Visits in the First 15 Months of Life: 2 Visits',
# 'W15_V03_2020C',#  - Well-Child Visits in the First 15 Months of Life: 3 Visits',
# 'W15_V04_2020C',#  - Well-Child Visits in the First 15 Months of Life: 4 Visits',
# 'W15_V05_2020C',#  - Well-Child Visits in the First 15 Months of Life: 5 Visits',
# 'W15',#_V06+_2020C - Well-Child Visits in the First 15 Months of Life: 6 or more Visits',
'W34_2020C'#  - Well-Child Visits in the Third, Fourth, Fifth and Sixth Years of Life'  		
           ]
           

overuse = [
#'NYU_EM_PCT_2016',#  - NYU ED Utilization Algorithm: Emergent, Primary Care Treatable',
'NYU_NON_EM_2016',#  - NYU ED Utilization Algorithm: Non-Emergent',
'AAB_2020C',#  - Avoidance of Antibiotic Treatment for Acute Bronchitis/Bronchiolitis (Total)',
#'APC_TOTAL_2019',#  - Use of Multiple Concurrent Antipsychotics in Children and Adolescents (Total)',
'HDO_2020',#  - Use of Opioids at High Dosage',
'LBP_2020C',#  - Use of Imaging Studies for Low Back Pain',
'UOP_NUM1_2020',#  - Use of Opioids from Multiple Providers (Multiple Prescribers)',
'UOP_NUM2_2020',#  - Use of Opioids from Multiple Providers (Multiple Pharmacies)',
'UOP_NUM3_2020',#  - Use of Opioids from Multiple Providers (Multiple Prescribers and Multiple Pharmacies)',
'URI_2020C',#  - Appropriate Treatment for Upper Respiratory Infection',
'CWP_2020C',#  - Appropriate Testing for Pharyngitis (Total)',
'IQI_21_TOTAL_2017'#,  - Cesarean Delivery Rate, Uncomplicated (Overall)',
#'IQI_34_TOTAL_2017'#  - Vaginal Birth After Cesarean (VBAC) Rate, All (Overall)'
          ]

race_ebm_df = ref.add_ebm_col(overuse, underuse, race_ebm_df)

# %%
race_ebm_df = ref.convert_cat(race_ebm_df)

# %%
#save separate datasets for underuse and overuse
race_ebm_df.to_csv(r'.../restricted /main_race_ebm_analysis.csv', index = False)

overuse_df = race_ebm_df[race_ebm_df['over/underuse'] == 'over']
overuse_df.to_csv(r'.../restricted /main_overuse_df.csv', index = False)

underuse_df = race_ebm_df[race_ebm_df['over/underuse'] == 'under']
underuse_df.to_csv(r'.../restricted /main_underuse_df.csv', index = False)

# %%
#read the datasets 
race_ebm_df = pd.read_csv ('.../restricted /main_race_ebm_analysis.csv')
over_df = pd.read_csv ('.../restricted /main_overuse_df.csv')
under_df = pd.read_csv ('.../restricted /main_underuse_df.csv')

# %%
#get the race proportion table
ref.race_prop_tab(race_ebm_df)
# Out:
# white       0.780401
# black       0.095212
# hispanic    0.086192
# api         0.036397
# aian        0.001566
# 2prace      0.000232
# Name: predicted_race, dtype: float64

# %%
#overuse underuse vs. race
ref.over_under_tab(race_ebm_df)
# Out:
#           white     black  hispanic       api      aian  2prace
# over   0.287607  0.257105  0.263403  0.354470  0.162222  0.3325
# under  0.407171  0.375201  0.356789  0.418663  0.277407  0.0000

# %%
#table for overuse measures by race 
ref.ebm_tab(over_df)
# Out:
#                                                        White     Black  \
# ebm_measure_label
# AAB_2020C - Avoidance of Antibiotic Treatment f...  0.553398  0.687500
# APC_TOTAL_2019 - Use of Multiple Concurrent Ant...  0.000000  0.000000
# CWP_2020C - Appropriate Testing for Pharyngitis...  0.731219  0.454545
# HDO_2020 - Use of Opioids at High Dosage            0.026059  0.000000
# IQI_21_TOTAL_2017 - Cesarean Delivery Rate, Unc...  0.270451  0.354839
# IQI_34_TOTAL_2017 - Vaginal Birth After Cesarea...  0.117647  0.230769
# LBP_2020C - Use of Imaging Studies for Low Back...  0.772989  0.756098
# NYU_EM_PCT_2016 - NYU ED Utilization Algorithm:...  0.201490  0.221696
# NYU_NON_EM_2016 - NYU ED Utilization Algorithm:...  0.171181  0.232587
# UOP_NUM1_2020 - Use of Opioids from Multiple Pr...  0.145251  0.132075
# UOP_NUM2_2020 - Use of Opioids from Multiple Pr...  0.036313  0.000000
# UOP_NUM3_2020 - Use of Opioids from Multiple Pr...  0.016760  0.000000
# URI_2020C - Appropriate Treatment for Upper Res...  0.894231  0.828571
#
#                                                     Hispanic       API  \
# ebm_measure_label
# AAB_2020C - Avoidance of Antibiotic Treatment f...  0.423077  0.750000
# APC_TOTAL_2019 - Use of Multiple Concurrent Ant...  0.000000       NaN
# CWP_2020C - Appropriate Testing for Pharyngitis...  0.523810  0.636364
# HDO_2020 - Use of Opioids at High Dosage            0.047619  0.000000
# IQI_21_TOTAL_2017 - Cesarean Delivery Rate, Unc...  0.264151  0.327869
# IQI_34_TOTAL_2017 - Vaginal Birth After Cesarea...  0.100000  0.076923
# LBP_2020C - Use of Imaging Studies for Low Back...  0.612903  0.882353
# NYU_EM_PCT_2016 - NYU ED Utilization Algorithm:...  0.206104  0.185906
# NYU_NON_EM_2016 - NYU ED Utilization Algorithm:...  0.197878  0.162063
# UOP_NUM1_2020 - Use of Opioids from Multiple Pr...  0.125000  0.000000
# UOP_NUM2_2020 - Use of Opioids from Multiple Pr...  0.000000  0.000000
# UOP_NUM3_2020 - Use of Opioids from Multiple Pr...  0.000000  0.000000
# URI_2020C - Appropriate Treatment for Upper Res...  0.806122  0.876923
#
#                                                         AIAN  2prace
# ebm_measure_label
# AAB_2020C - Avoidance of Antibiotic Treatment f...       NaN     NaN
# APC_TOTAL_2019 - Use of Multiple Concurrent Ant...       NaN     NaN
# CWP_2020C - Appropriate Testing for Pharyngitis...       NaN     NaN
# HDO_2020 - Use of Opioids at High Dosage            0.000000     NaN
# IQI_21_TOTAL_2017 - Cesarean Delivery Rate, Unc...  1.000000    0.00
# IQI_34_TOTAL_2017 - Vaginal Birth After Cesarea...  0.000000     NaN
# LBP_2020C - Use of Imaging Studies for Low Back...  1.000000     NaN
# NYU_EM_PCT_2016 - NYU ED Utilization Algorithm:...  0.066667    0.33
# NYU_NON_EM_2016 - NYU ED Utilization Algorithm:...  0.097500    0.00
# UOP_NUM1_2020 - Use of Opioids from Multiple Pr...  0.500000     NaN
# UOP_NUM2_2020 - Use of Opioids from Multiple Pr...  0.000000     NaN
# UOP_NUM3_2020 - Use of Opioids from Multiple Pr...  0.000000     NaN
# URI_2020C - Appropriate Treatment for Upper Res...       NaN    1.00

# %%
#table for underuse measures by race 
ref.ebm_tab(under_df)
# Out:
#                                                        White     Black  \
# ebm_measure_label
# ADD_R1_2020C - Follow-Up Care for Children Pres...  0.526316  1.000000
# ADD_R2_2020C - Follow-Up Care for Children Pres...  0.555556       NaN
# APP_TOTAL_2020 - Use of First-Line Psychosocial...  0.545455  1.000000
# CDC_A1C_T_2020C - Comprehensive Diabetes Care: ...  0.822818  0.807487
# CHL_TOTAL_2020C - Chlamydia Screening in Women ...  0.340292  0.529412
# COL_NON_MCR_2020C - Colorectal Cancer Screening     0.232938  0.350000
# FUA30_TOTAL_2020 - Follow-Up After Emergency De...  0.200000  0.000000
# FUA7_TOTAL_2020 - Follow-Up After Emergency Dep...  0.200000  0.000000
# FUH_30_TOTAL_2020 - Follow-Up After Hospitaliza...  0.726190  0.500000
# FUH_7_TOTAL_2020 - Follow-Up After Hospitalizat...  0.511628  0.500000
# FUM_30_TOTAL_2020 - Follow-Up After Emergency D...  0.666667  0.666667
# FUM_7_TOTAL_2020 - Follow-Up After Emergency De...  0.400000  0.571429
# IMA_HPV_2020 - Immunizations for Adolescents: H...  0.082278  0.000000
# IMA_MEN_2020 - Immunizations for Adolescents: M...  0.354430  0.000000
# IMA_TD_2020 - Immunizations for Adolescents: Td...  0.316456  0.000000
# NCS_2020 - Non-Recommended Cervical Cancer Scre...  0.005198  0.000000
# NYU_EM_ED_PA_2016 - NYU ED Utilization Algorith...  0.040674  0.062576
# PPC_PN_2020C - Prenatal and Postpartum Care: Pr...  0.328622  0.535714
# PPC_PP_2020C - Prenatal and Postpartum Care: Po...  0.480565  0.535714
# PQA_BB_2018 - Percentage of members 18 years an...  0.668797  0.446429
# PQA_RASA_2018 - Percentage of members 18 years ...  0.756384  0.594771
# SAA_2020 - Adherence to Antipsychotic Medicatio...  0.777778  0.000000
# SPC_R1_TOTAL_2020 - Statin Therapy for Patients...  0.928571  1.000000
# SPC_R2_TOTAL_2020 - Statin Therapy for Patients...  0.769231  0.000000
# W15_V00_2020C - Well-Child Visits in the First ...  0.018018  0.000000
# W15_V01_2020C - Well-Child Visits in the First ...  0.009009  0.000000
# W15_V02_2020C - Well-Child Visits in the First ...  0.027027  0.000000
# W15_V03_2020C - Well-Child Visits in the First ...  0.018018  0.000000
# W15_V04_2020C - Well-Child Visits in the First ...  0.063063  0.000000
# W15_V05_2020C - Well-Child Visits in the First ...  0.198198  0.666667
# W15_V06+_2020C - Well-Child Visits in the First...  0.666667  0.333333
# W34_2020C - Well-Child Visits in the Third, Fou...  0.700759  0.562500
#
#                                                     Hispanic       API  \
# ebm_measure_label
# ADD_R1_2020C - Follow-Up Care for Children Pres...  1.000000       NaN
# ADD_R2_2020C - Follow-Up Care for Children Pres...       NaN       NaN
# APP_TOTAL_2020 - Use of First-Line Psychosocial...       NaN       NaN
# CDC_A1C_T_2020C - Comprehensive Diabetes Care: ...  0.760870  0.873239
# CHL_TOTAL_2020C - Chlamydia Screening in Women ...  0.413793  0.357143
# COL_NON_MCR_2020C - Colorectal Cancer Screening     0.166667  0.161290
# FUA30_TOTAL_2020 - Follow-Up After Emergency De...  0.000000  0.000000
# FUA7_TOTAL_2020 - Follow-Up After Emergency Dep...  0.000000  0.000000
# FUH_30_TOTAL_2020 - Follow-Up After Hospitaliza...  0.800000  0.750000
# FUH_7_TOTAL_2020 - Follow-Up After Hospitalizat...  0.600000  0.750000
# FUM_30_TOTAL_2020 - Follow-Up After Emergency D...  0.500000  1.000000
# FUM_7_TOTAL_2020 - Follow-Up After Emergency De...  0.400000  0.000000
# IMA_HPV_2020 - Immunizations for Adolescents: H...  0.000000  0.166667
# IMA_MEN_2020 - Immunizations for Adolescents: M...  0.153846  0.250000
# IMA_TD_2020 - Immunizations for Adolescents: Td...  0.076923  0.250000
# NCS_2020 - Non-Recommended Cervical Cancer Scre...  0.000000  0.000000
# NYU_EM_ED_PA_2016 - NYU ED Utilization Algorith...  0.047996  0.034508
# PPC_PN_2020C - Prenatal and Postpartum Care: Pr...  0.480000  0.322581
# PPC_PP_2020C - Prenatal and Postpartum Care: Po...  0.360000  0.516129
# PQA_BB_2018 - Percentage of members 18 years an...  0.608696  0.619048
# PQA_RASA_2018 - Percentage of members 18 years ...  0.630435  0.674157
# SAA_2020 - Adherence to Antipsychotic Medicatio...  0.000000  0.000000
# SPC_R1_TOTAL_2020 - Statin Therapy for Patients...  1.000000  1.000000
# SPC_R2_TOTAL_2020 - Statin Therapy for Patients...  1.000000  0.000000
# W15_V00_2020C - Well-Child Visits in the First ...  0.000000  0.000000
# W15_V01_2020C - Well-Child Visits in the First ...  0.000000  0.000000
# W15_V02_2020C - Well-Child Visits in the First ...  0.000000  0.000000
# W15_V03_2020C - Well-Child Visits in the First ...  0.000000  0.000000
# W15_V04_2020C - Well-Child Visits in the First ...  0.250000  0.125000
# W15_V05_2020C - Well-Child Visits in the First ...  0.000000  0.250000
# W15_V06+_2020C - Well-Child Visits in the First...  0.750000  0.625000
# W34_2020C - Well-Child Visits in the Third, Fou...  0.662338  0.671569
#
#                                                         AIAN  2prace
# ebm_measure_label
# ADD_R1_2020C - Follow-Up Care for Children Pres...       NaN     NaN
# ADD_R2_2020C - Follow-Up Care for Children Pres...       NaN     NaN
# APP_TOTAL_2020 - Use of First-Line Psychosocial...       NaN     NaN
# CDC_A1C_T_2020C - Comprehensive Diabetes Care: ...  1.000000     NaN
# CHL_TOTAL_2020C - Chlamydia Screening in Women ...  0.250000     0.0
# COL_NON_MCR_2020C - Colorectal Cancer Screening     0.000000     NaN
# FUA30_TOTAL_2020 - Follow-Up After Emergency De...       NaN     NaN
# FUA7_TOTAL_2020 - Follow-Up After Emergency Dep...       NaN     NaN
# FUH_30_TOTAL_2020 - Follow-Up After Hospitaliza...       NaN     NaN
# FUH_7_TOTAL_2020 - Follow-Up After Hospitalizat...       NaN     NaN
# FUM_30_TOTAL_2020 - Follow-Up After Emergency D...       NaN     NaN
# FUM_7_TOTAL_2020 - Follow-Up After Emergency De...       NaN     NaN
# IMA_HPV_2020 - Immunizations for Adolescents: H...  0.000000     NaN
# IMA_MEN_2020 - Immunizations for Adolescents: M...  0.000000     NaN
# IMA_TD_2020 - Immunizations for Adolescents: Td...  0.000000     NaN
# NCS_2020 - Non-Recommended Cervical Cancer Scre...  0.000000     0.0
# NYU_EM_ED_PA_2016 - NYU ED Utilization Algorith...  0.054444     0.0
# PPC_PN_2020C - Prenatal and Postpartum Care: Pr...       NaN     NaN
# PPC_PP_2020C - Prenatal and Postpartum Care: Po...       NaN     NaN
# PQA_BB_2018 - Percentage of members 18 years an...  1.000000     NaN
# PQA_RASA_2018 - Percentage of members 18 years ...  0.750000     NaN
# SAA_2020 - Adherence to Antipsychotic Medicatio...       NaN     NaN
# SPC_R1_TOTAL_2020 - Statin Therapy for Patients...       NaN     NaN
# SPC_R2_TOTAL_2020 - Statin Therapy for Patients...       NaN     NaN
# W15_V00_2020C - Well-Child Visits in the First ...       NaN     NaN
# W15_V01_2020C - Well-Child Visits in the First ...       NaN     NaN
# W15_V02_2020C - Well-Child Visits in the First ...       NaN     NaN
# W15_V03_2020C - Well-Child Visits in the First ...       NaN     NaN
# W15_V04_2020C - Well-Child Visits in the First ...       NaN     NaN
# W15_V05_2020C - Well-Child Visits in the First ...       NaN     NaN
# W15_V06+_2020C - Well-Child Visits in the First...       NaN     NaN
# W34_2020C - Well-Child Visits in the Third, Fou...       NaN     0.0
